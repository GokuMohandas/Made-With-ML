# %% [markdown]
# # Title

# %% [markdown]
# <img src="https://raw.githubusercontent.com/GokuMohandas/practicalAI/master/images/logo.png" width=150>
#
# text

# %% [markdown]
# # Overview

# %% [markdown]
# * **Objective:**
# * **Advantages:**
# * **Disadvantages:**
# * **Miscellaneous:**
