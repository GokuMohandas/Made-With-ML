# %% [markdown]
# #Multilayer Perceptron (MLP)
#
# In this lesson, we will explore multilayer perceptrons (MLPs) which are a basic type of neural network. We'll first motivate non-linear activation functions by trying to fit a linear model (logistic regression) on our non-linear spiral data. Then we'll implement an MLP using just NumPy and then with TensorFlow + Keras.

# %% [markdown]
# <a href="https://github.com/madewithml/practicalAI/blob/master/notebooks/basic_ml/06_Multilayer_Perceptrons.ipynb" role="button"><img class="notebook-badge-image" src="https://img.shields.io/static/v1?label=&amp;message=View%20On%20GitHub&amp;color=586069&amp;logo=github&amp;labelColor=2f363d"></a>&nbsp;
# <a href="https://colab.research.google.com/github/madewithml/practicalAI/blob/master/notebooks/basic_ml/06_Multilayer_Perceptrons.ipynb"><img class="notebook-badge-image" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a>

# %% [markdown]
# # Overview

# %% [markdown]
# Our goal is to learn a model  𝑦̂   that models  𝑦  given  𝑋 . You'll notice that neural networks are just extensions of the generalized linear methods we've seen so far but with non-linear activation functions since our data will be highly non-linear.
#
# <img src="https://raw.githubusercontent.com/practicalAI/images/master/basic_ml/06_Multilayer_Perceptron/nn.png" width="550">
#
# $z_1 = XW_1$
#
# $a_1 = f(z_1)$
#
# $z_2 = a_1W_2$
#
# $\hat{y} = softmax(z_2)$ # classification
#
# * $X$ = inputs | $\in \mathbb{R}^{NXD}$ ($D$ is the number of features)
# * $W_1$ = 1st layer weights | $\in \mathbb{R}^{DXH}$ ($H$ is the number of hidden units in layer 1)
# * $z_1$ = outputs from first layer  $\in \mathbb{R}^{NXH}$
# * $f$ = non-linear activation function
# * $a_1$ = activation applied first layer's outputs | $\in \mathbb{R}^{NXH}$
# * $W_2$ = 2nd layer weights | $\in \mathbb{R}^{HXC}$ ($C$ is the number of classes)
# * $z_2$ = outputs from second layer  $\in \mathbb{R}^{NXH}$
# * $\hat{y}$ = prediction | $\in \mathbb{R}^{NXC}$ ($N$ is the number of samples)

# %% [markdown]
# * **Objective:**  Predict the probability of class $y$ given the inputs $X$. Non-linearity is introduced to model the complex, non-linear data.
# * **Advantages:**
#   * Can model non-linear patterns in the data really well.
# * **Disadvantages:**
#   * Overfits easily.
#   * Computationally intensive as network increases in size.
#   * Not easily interpretable.
# * **Miscellaneous:** Future neural network architectures that we'll see use the MLP as a modular unit for feed forward operations (affine transformation (XW) followed by a non-linear operation).

# %% [markdown]
# **Note**: We're going to leave out the bias terms $\beta$ to avoid further crowding the backpropagation calculations.

# %% [markdown]
# # Data

# %% [markdown]
# ## Load data

# %% [markdown]
# Download non-linear spiral data for a classification task.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import urllib

# %%
SEED = 1234
DATA_FILE = "spiral.csv"

# %%
# Set seed for reproducibility
np.random.seed(SEED)

# %%
# Load data from GitHub to this notebook's local drive
url = "https://raw.githubusercontent.com/madewithml/practicalAI/master/data/spiral.csv"
response = urllib.request.urlopen(url)
html = response.read()
with open(DATA_FILE, 'wb') as fp:
    fp.write(html)

# %%
# Load data
df = pd.read_csv(DATA_FILE, header=0)
X = df[['X1', 'X2']].values
y = df['color'].values
df.head(5)
# Out:
#          X1        X2 color
# 0  0.000000  0.000000    c1
# 1 -0.000457  0.001951    c1
# 2  0.001194  0.003826    c1
# 3 -0.000231  0.006008    c1
# 4 -0.000896  0.007966    c1

# %%
print ("X: ", np.shape(X))
print ("y: ", np.shape(y))
# Out:
# X:  (1500, 2)
# y:  (1500,)

# %%
# Visualize data
plt.title("Generated non-linear data")
colors = {'c1': 'red', 'c2': 'yellow', 'c3': 'blue'}
plt.scatter(X[:, 0], X[:, 1], c=[colors[_y] for _y in y], edgecolors='k', s=25)
plt.show()

# %% [markdown]
# ## Split data

# %%
import collections
from sklearn.model_selection import train_test_split

# %%
TRAIN_SIZE = 0.7
VAL_SIZE = 0.15
TEST_SIZE = 0.15
SHUFFLE = True

# %%
def train_val_test_split(X, y, val_size, test_size, shuffle):
    """Split data into train/val/test datasets.
    """
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=test_size, stratify=y, shuffle=shuffle)
    X_train, X_val, y_train, y_val = train_test_split(
        X_train, y_train, test_size=val_size, stratify=y_train, shuffle=shuffle)
    return X_train, X_val, X_test, y_train, y_val, y_test

# %%
# Create data splits
X_train, X_val, X_test, y_train, y_val, y_test = train_val_test_split(
    X=X, y=y, val_size=VAL_SIZE, test_size=TEST_SIZE, shuffle=SHUFFLE)
class_counts = dict(collections.Counter(y))
print (f"X_train: {X_train.shape}, y_train: {y_train.shape}")
print (f"X_val: {X_val.shape}, y_val: {y_val.shape}")
print (f"X_test: {X_test.shape}, y_test: {y_test.shape}")
print (f"Sample point: {X_train[0]} → {y_train[0]}")
print (f"Classes: {class_counts}")
# Out:
# X_train: (1083, 2), y_train: (1083,)
# X_val: (192, 2), y_val: (192,)
# X_test: (225, 2), y_test: (225,)
# Sample point: [ 0.23623443 -0.59618506] → c1
# Classes: {'c1': 500, 'c3': 500, 'c2': 500}

# %% [markdown]
# ## Label encoder

# %%
from sklearn.preprocessing import LabelEncoder

# %%
# Output vectorizer
y_tokenizer = LabelEncoder()

# %%
# Fit on train data
y_tokenizer = y_tokenizer.fit(y_train)
classes = list(y_tokenizer.classes_)
print (f"classes: {classes}")
# Out:
# classes: ['c1', 'c2', 'c3']

# %%
# Convert labels to tokens
print (f"y_train[0]: {y_train[0]}")
y_train = y_tokenizer.transform(y_train)
y_val = y_tokenizer.transform(y_val)
y_test = y_tokenizer.transform(y_test)
print (f"y_train[0]: {y_train[0]}")
# Out:
# y_train[0]: c1
# y_train[0]: 0

# %%
# Class weights
counts = collections.Counter(y_train)
class_weights = {_class: 1.0/count for _class, count in counts.items()}
print (f"class counts: {counts},\nclass weights: {class_weights}")
# Out:
# class counts: Counter({0: 361, 2: 361, 1: 361}),
# class weights: {0: 0.002770083102493075, 2: 0.002770083102493075, 1: 0.002770083102493075}

# %% [markdown]
# ## Standardize data

# %% [markdown]
# We need to standardize our data (zero mean and unit variance) in order to optimize quickly. We're only going to standardize the inputs X because out outputs y are class values.

# %%
from sklearn.preprocessing import StandardScaler

# %%
# Standardize the data (mean=0, std=1) using training data
X_scaler = StandardScaler().fit(X_train)

# %%
# Apply scaler on training and test data (don't standardize outputs for classification)
X_train = X_scaler.transform(X_train)
X_val = X_scaler.transform(X_val)
X_test = X_scaler.transform(X_test)

# %%
# Check (means should be ~0 and std should be ~1)
print (f"X_train[0]: mean: {np.mean(X_train[:, 0], axis=0):.1f}, std: {np.std(X_train[:, 0], axis=0):.1f}")
print (f"X_train[1]: mean: {np.mean(X_train[:, 1], axis=0):.1f}, std: {np.std(X_train[:, 1], axis=0):.1f}")
print (f"X_val[0]: mean: {np.mean(X_val[:, 0], axis=0):.1f}, std: {np.std(X_val[:, 0], axis=0):.1f}")
print (f"X_val[1]: mean: {np.mean(X_val[:, 1], axis=0):.1f}, std: {np.std(X_val[:, 1], axis=0):.1f}")
print (f"X_test[0]: mean: {np.mean(X_test[:, 0], axis=0):.1f}, std: {np.std(X_test[:, 0], axis=0):.1f}")
print (f"X_test[1]: mean: {np.mean(X_test[:, 1], axis=0):.1f}, std: {np.std(X_test[:, 1], axis=0):.1f}")
# Out:
# X_train[0]: mean: 0.0, std: 1.0
# X_train[1]: mean: 0.0, std: 1.0
# X_val[0]: mean: 0.1, std: 1.0
# X_val[1]: mean: 0.0, std: 1.0
# X_test[0]: mean: 0.1, std: 1.0
# X_test[1]: mean: -0.1, std: 0.9

# %% [markdown]
# # Linear model

# %% [markdown]
# Before we get to our neural network, we're going to motivate non-linear activation functions by implementing a generalized linear model (logistic regression). We'll see why linear models (with linear activations) won't suffice for our dataset.

# %%
# %tensorflow_version 2.x
import tensorflow as tf
# Out:
# TensorFlow 2.x selected.

# %%
# Set seed for reproducibility
tf.random.set_seed(SEED)

# %% [markdown]
# ## Model

# %%
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model

# %%
INPUT_DIM = X_train.shape[1] # X is 2-dimensional
HIDDEN_DIM = 100
NUM_CLASSES = len(classes) # 3 classes

# %%
class LinearModel(Model):
    def __init__(self, hidden_dim, num_classes):
        super(LinearModel, self).__init__(name='linear_model')
        self.fc1 = Dense(units=hidden_dim, activation='linear', name='W1')
        self.fc2 = Dense(units=num_classes, activation='softmax', name='W2')
        
    def call(self, x_in, training=False):
        z = self.fc1(x_in)
        y_pred = self.fc2(z)
        return y_pred

    def summary(self, input_shape):
        x_in = Input(shape=input_shape, name='X')
        summary = Model(inputs=x_in, outputs=self.call(x_in), name=self.name)
        summary.summary() # parameter summary
        print ("\n\nWEIGHTS:") # weights summary
        for layer in self.layers:
            print ("_"*50)
            print (layer.name)
            for w in layer.weights:
                print (f"\t{w.name} → {w.shape}")
        print ("\n\nFORWARD PASS:")
        return plot_model(summary, show_shapes=True) # forward pass

# %%
# Initialize model
model = LinearModel(hidden_dim=HIDDEN_DIM, num_classes=NUM_CLASSES)

# %%
# Summary
model.summary(input_shape=(INPUT_DIM,))
# Out:
# Model: "linear_model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# X (InputLayer)               [(None, 2)]               0
# _________________________________________________________________
# W1 (Dense)                   (None, 100)               300
# _________________________________________________________________
# W2 (Dense)                   (None, 3)                 303
# =================================================================
# Total params: 603
# Trainable params: 603
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Training

# %%
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.metrics import SparseCategoricalAccuracy
from tensorflow.keras.optimizers import Adam

# %%
LEARNING_RATE = 1e-2
NUM_EPOCHS = 10
BATCH_SIZE = 32

# %%
# Compile
model.compile(optimizer=Adam(lr=LEARNING_RATE),
              loss=SparseCategoricalCrossentropy(),
              metrics=[SparseCategoricalAccuracy()])

# %%
# Training
model.fit(x=X_train, 
          y=y_train,
          validation_data=(X_val, y_val),
          epochs=NUM_EPOCHS,
          batch_size=BATCH_SIZE,
          class_weight=class_weights,
          shuffle=False,
          verbose=1)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 1083 samples, validate on 192 samples
# Epoch 1/10
# 1083/1083 [==============================] - 2s 2ms/sample - loss: 0.0022 - sparse_categorical_accuracy: 0.5199 - val_loss: 0.0021 - val_sparse_categorical_accuracy: 0.4948
# Epoch 2/10
# 1083/1083 [==============================] - 0s 99us/sample - loss: 0.0021 - sparse_categorical_accuracy: 0.5254 - val_loss: 0.0021 - val_sparse_categorical_accuracy: 0.5052
# Epoch 3/10
# 1083/1083 [==============================] - 0s 100us/sample - loss: 0.0021 - sparse_categorical_accuracy: 0.5263 - val_loss: 0.0021 - val_sparse_categorical_accuracy: 0.5104
# Epoch 4/10
# 1083/1083 [==============================] - 0s 97us/sample - loss: 0.0021 - sparse_categorical_accuracy: 0.5254 - val_loss: 0.0021 - val_sparse_categorical_accuracy: 0.5104
# Epoch 5/10
# 1083/1083 [==============================] - 0s 93us/sample - loss: 0.0021 - sparse_categorical_accuracy: 0.5254 - val_loss: 0.0021 - val_sparse_categorical_accuracy: 0.5000
# Epoch 6/10
# 1083/1083 [==============================] - 0s 97us/sample - loss: 0.0021 - sparse_categorical_accuracy: 0.5254 - val_loss: 0.0021 - val_sparse_categorical_accuracy: 0.5000
# Epoch 7/10
# 1083/1083 [==============================] - 0s 95us/sample - loss: 0.0021 - sparse_categorical_accuracy: 0.5235 - val_loss: 0.0021 - val_sparse_categorical_accuracy: 0.5000
# Epoch 8/10
# 1083/1083 [==============================] - 0s 93us/sample - loss: 0.0021 - sparse_categorical_accuracy: 0.5226 - val_loss: 0.0021 - val_sparse_categorical_accuracy: 0.5000
# Epoch 9/10
# 1083/1083 [==============================] - 0s 113us/sample - loss: 0.0021 - sparse_categorical_accuracy: 0.5235 - val_loss: 0.0021 - val_sparse_categorical_accuracy: 0.5052
# Epoch 10/10
# 1083/1083 [==============================] - 0s 113us/sample - loss: 0.0021 - sparse_categorical_accuracy: 0.5245 - val_loss: 0.0021 - val_sparse_categorical_accuracy: 0.5052

# %% [markdown]
# ## Evaluation

# %%
import itertools
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %%
def plot_confusion_matrix(y_true, y_pred, classes, cmap=plt.cm.Blues):
    """Plot a confusion matrix using ground truth and predictions."""
    # Confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    cm_norm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    #  Figure
    fig = plt.figure()
    ax = fig.add_subplot(111)
    cax = ax.matshow(cm, cmap=plt.cm.Blues)
    fig.colorbar(cax)

    # Axis
    plt.title("Confusion matrix")
    plt.ylabel("True label")
    plt.xlabel("Predicted label")
    ax.set_xticklabels([''] + classes)
    ax.set_yticklabels([''] + classes)
    ax.xaxis.set_label_position('bottom') 
    ax.xaxis.tick_bottom()

    # Values
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, f"{cm[i, j]:d} ({cm_norm[i, j]*100:.1f}%)",
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    # Display
    plt.show()

# %%
def plot_multiclass_decision_boundary(model, X, y, savefig_fp=None):
    """Plot the multiclass decision boundary for a model that accepts 2D inputs.

    Arguments:
        model {function} -- trained model with function model.predict(x_in).
        X {numpy.ndarray} -- 2D inputs with shape (N, 2).
        y {numpy.ndarray} -- 1D outputs with shape (N,).
    """
    # Axis boundaries
    x_min, x_max = X[:, 0].min() - 0.1, X[:, 0].max() + 0.1
    y_min, y_max = X[:, 1].min() - 0.1, X[:, 1].max() + 0.1
    xx, yy = np.meshgrid(np.linspace(x_min, x_max, 101),
                         np.linspace(y_min, y_max, 101))

    # Create predictions
    x_in = np.c_[xx.ravel(), yy.ravel()]
    y_pred = model.predict(x_in)
    y_pred = np.argmax(y_pred, axis=1).reshape(xx.shape)

    # Plot decision boundary
    plt.contourf(xx, yy, y_pred, cmap=plt.cm.Spectral, alpha=0.8)
    plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=plt.cm.RdYlBu)
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())

    # Plot
    if savefig_fp:
        plt.savefig(savefig_fp, format='png')

# %%
# Predictions
pred_train = model.predict(X_train) 
pred_test = model.predict(X_test)
print (f"sample probability: {pred_test[0]}")
pred_train = np.argmax(pred_train, axis=1)
pred_test = np.argmax(pred_test, axis=1)
print (f"sample class: {pred_test[0]}")
# Out:
# sample probability: [0.02820206 0.13940965 0.83238834]
# sample class: 2

# %%
# Accuracy
train_acc = accuracy_score(y_train, pred_train)
test_acc = accuracy_score(y_test, pred_test)
print (f"train acc: {train_acc:.2f}, test acc: {test_acc:.2f}")
# Out:
# train acc: 0.53, test acc: 0.54

# %%
# Metrics
plot_confusion_matrix(y_test, pred_test, classes=classes)
print (classification_report(y_test, pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.51      0.59      0.55        75
#            1       0.50      0.44      0.47        75
#            2       0.60      0.59      0.59        75
#
#     accuracy                           0.54       225
#    macro avg       0.54      0.54      0.54       225
# weighted avg       0.54      0.54      0.54       225

# %%
# Visualize the decision boundary
plt.figure(figsize=(12,5))
plt.subplot(1, 2, 1)
plt.title("Train")
plot_multiclass_decision_boundary(model=model, X=X_train, y=y_train)
plt.subplot(1, 2, 2)
plt.title("Test")
plot_multiclass_decision_boundary(model=model, X=X_test, y=y_test)
plt.show()

# %% [markdown]
# # Activation functions

# %% [markdown]
# Using the generalized linear method (logistic regression) yielded poor results because of the non-linearity present in our data yet our activation functions were linear. We need to use an activation function that can allow our model to learn and map the non-linearity in our data. There are many different options so let's explore a few.

# %%
from tensorflow.keras.activations import relu
from tensorflow.keras.activations import sigmoid
from tensorflow.keras.activations import tanh

# %%
# Fig size
plt.figure(figsize=(12,3))

# Data
x = np.arange(-5., 5., 0.1)

# Sigmoid activation (constrain a value between 0 and 1.)
plt.subplot(1, 3, 1)
plt.title("Sigmoid activation")
y = sigmoid(x)
plt.plot(x, y)

# Tanh activation (constrain a value between -1 and 1.)
plt.subplot(1, 3, 2)
y = tanh(x)
plt.title("Tanh activation")
plt.plot(x, y)

# Relu (clip the negative values to 0)
plt.subplot(1, 3, 3)
y = relu(x)
plt.title("ReLU activation")
plt.plot(x, y)

# Show plots
plt.show()

# %% [markdown]
# The ReLU activation function ($max(0,z)$) is by far the most widely used activation function for neural networks. But as you can see, each activation function has its own constraints so there are circumstances where you'll want to use different ones. For example, if we need to constrain our outputs between 0 and 1, then the sigmoid activation is the best choice.

# %% [markdown]
# **NOTE**: In some cases, using a ReLU activation function may not be sufficient. For instance, when the outputs from our neurons are mostly negative, the activation function will produce zeros. This effectively creates a "dying ReLU" and a recovery is unlikely. To mitigate this effect, we could lower the learning rate or use [alternative ReLU activations](https://medium.com/tinymind/a-practical-guide-to-relu-b83ca804f1f7), ex. leaky ReLU or parametric ReLU (PReLU), which have a small slope for negative neuron outputs.

# %% [markdown]
# # NumPy
#
# Now let's create our multilayer perceptron (MLP) which is going to be exactly like the logistic regression model but with the activation function to map the non-linearity in our data.
#
# **NOTE**: It's normal to find the math and code in this section slightly complex. You can still read each of the steps to build intuition for when we implement this using TensorFlow + Keras.

# %% [markdown]
# Our goal is to learn a model  𝑦̂   that models  𝑦  given  𝑋 . You'll notice that neural networks are just extensions of the generalized linear methods we've seen so far but with non-linear activation functions since our data will be highly non-linear.
#
# $z_1 = XW_1$
#
# $a_1 = f(z_1)$
#
# $z_2 = a_1W_2$
#
# $\hat{y} = softmax(z_2)$ # classification
#
# * $X$ = inputs | $\in \mathbb{R}^{NXD}$ ($D$ is the number of features)
# * $W_1$ = 1st layer weights | $\in \mathbb{R}^{DXH}$ ($H$ is the number of hidden units in layer 1)
# * $z_1$ = outputs from first layer  $\in \mathbb{R}^{NXH}$
# * $f$ = non-linear activation function
# * $a_1$ = activation applied first layer's outputs | $\in \mathbb{R}^{NXH}$
# * $W_2$ = 2nd layer weights | $\in \mathbb{R}^{HXC}$ ($C$ is the number of classes)
# * $z_2$ = outputs from second layer  $\in \mathbb{R}^{NXH}$
# * $\hat{y}$ = prediction | $\in \mathbb{R}^{NXC}$ ($N$ is the number of samples)

# %% [markdown]
# ## Initialize weights

# %% [markdown]
# 1. Randomly initialize the model's weights $W$ (we'll cover more effective initialization strategies later in this lesson).

# %%
# Initialize first layer's weights
W1 = 0.01 * np.random.randn(INPUT_DIM, HIDDEN_DIM)
b1 = np.zeros((1, HIDDEN_DIM))
print (f"W1: {W1.shape}")
print (f"b1: {b1.shape}")
# Out:
# W1: (2, 100)
# b1: (1, 100)

# %% [markdown]
# ## Model

# %% [markdown]
# 2. Feed inputs $X$ into the model to do the forward pass and receive the probabilities.

# %% [markdown]
# First we pass the inputs into the first layer.
#   * $z_1 = XW_1$

# %%
# z1 = [NX2] · [2X100] + [1X100] = [NX100]
z1 = np.dot(X_train, W1) + b1
print (f"z1: {z1.shape}")
# Out:
# z1: (1083, 100)

# %% [markdown]
# Next we apply the non-linear activation function, ReLU ($max(0,z)$) in this case.
#   * $a_1 = f(z_1)$

# %%
# Apply activation function
a1 = np.maximum(0, z1) # ReLU
print (f"a_1: {a1.shape}")
# Out:
# a_1: (1083, 100)

# %% [markdown]
# We pass the activations to the second layer to get our logits.
#   * $z_2 = a_1W_2$

# %%
# Initialize second layer's weights
W2 = 0.01 * np.random.randn(HIDDEN_DIM, NUM_CLASSES)
b2 = np.zeros((1, NUM_CLASSES))
print (f"W2: {W2.shape}")
print (f"b2: {b2.shape}")
# Out:
# W2: (100, 3)
# b2: (1, 3)

# %%
# z2 = logits = [NX100] · [100X3] + [1X3] = [NX3]
logits = np.dot(a1, W2) + b2
print (f"logits: {logits.shape}")
print (f"sample: {logits[0]}")
# Out:
# logits: (1083, 3)
# sample: [ 0.0004134   0.0002782  -0.00118021]

# %% [markdown]
# We'll apply the softmax function to normalize the logits and btain class probabilities.
#   * $\hat{y} = softmax(z_2)$

# %%
# Normalization via softmax to obtain class probabilities
exp_logits = np.exp(logits)
y_hat = exp_logits / np.sum(exp_logits, axis=1, keepdims=True)
print (f"y_hat: {y_hat.shape}")
print (f"sample: {y_hat[0]}")
# Out:
# y_hat: (1083, 3)
# sample: [0.33352539 0.3334803  0.33299431]

# %% [markdown]
# ## Loss

# %% [markdown]
# 3. Compare the predictions $\hat{y}$ (ex.  [0.3, 0.3, 0.4]]) with the actual target values $y$ (ex. class 2 would look like [0, 0, 1]) with the objective (cost) function to determine loss $J$. A common objective function for classification tasks is cross-entropy loss.
#   * $J(\theta) = - \sum_i ln(\hat{y_i}) = - \sum_i ln (\frac{e^{X_iW_y}}{\sum_j e^{X_iW}}) $

# %%
# Loss
correct_class_logprobs = -np.log(y_hat[range(len(y_hat)), y_train])
loss = np.sum(correct_class_logprobs) / len(y_train)

# %% [markdown]
# ## Gradients

# %% [markdown]
# 4. Calculate the gradient of loss $J(\theta)$ w.r.t to the model weights.
#
# The gradient of the loss w.r.t to W2 is the same as the gradients from logistic regression since $\hat{y} = softmax(z_2)$.
#  * $\frac{\partial{J}}{\partial{W_{2j}}} = \frac{\partial{J}}{\partial{\hat{y}}}\frac{\partial{\hat{y}}}{\partial{W_{2j}}} = - \frac{1}{\hat{y}}\frac{\partial{\hat{y}}}{\partial{W_{2j}}} = - \frac{1}{\frac{e^{W_{2y}a_1}}{\sum_j e^{a_1W}}}\frac{\sum_j e^{a_1W}e^{a_1W_{2y}}0 - e^{a_1W_{2y}}e^{a_1W_{2j}}a_1}{(\sum_j e^{a_1W})^2} = \frac{a_1e^{a_1W_{2j}}}{\sum_j e^{a_1W}} = a_1\hat{y}$
#   * $\frac{\partial{J}}{\partial{W_{2y}}} = \frac{\partial{J}}{\partial{\hat{y}}}\frac{\partial{\hat{y}}}{\partial{W_{2y}}} = - \frac{1}{\hat{y}}\frac{\partial{\hat{y}}}{\partial{W_{2y}}} = - \frac{1}{\frac{e^{W_{2y}a_1}}{\sum_j e^{a_1W}}}\frac{\sum_j e^{a_1W}e^{a_1W_{2y}}a_1 - e^{a_1W_{2y}}e^{a_1W_{2y}}a_1}{(\sum_j e^{a_1W})^2} = \frac{1}{\hat{y}}(a_1\hat{y} - a_1\hat{y}^2) = a_1(\hat{y}-1)$
#
#   The gradient of the loss w.r.t W1 is a bit trickier since we have to backpropagate through two sets of weights.
#   * $ \frac{\partial{J}}{\partial{W_1}} = \frac{\partial{J}}{\partial{\hat{y}}} \frac{\partial{\hat{y}}}{\partial{a_1}}  \frac{\partial{a_1}}{\partial{z_1}}  \frac{\partial{z_1}}{\partial{W_1}}  = W_2(\partial{scores})(\partial{ReLU})X $

# %%
# dJ/dW2
dscores = y_hat
dscores[range(len(y_hat)), y_train] -= 1
dscores /= len(y_train)
dW2 = np.dot(a1.T, dscores)
db2 = np.sum(dscores, axis=0, keepdims=True)

# %%
# dJ/dW1
dhidden = np.dot(dscores, W2.T)
dhidden[a1 <= 0] = 0 # ReLu backprop
dW1 = np.dot(X_train.T, dhidden)
db1 = np.sum(dhidden, axis=0, keepdims=True)

# %% [markdown]
# ## Update weights

# %% [markdown]
# 5. Update the weights $W$ using a small learning rate $\alpha$. The updates will penalize the probabiltiy for the incorrect classes (j) and encourage a higher probability for the correct class (y).
#   * $W_i = W_i - \alpha\frac{\partial{J}}{\partial{W_i}}$

# %%
# Update weights
W1 += -LEARNING_RATE * dW1
b1 += -LEARNING_RATE * db1
W2 += -LEARNING_RATE * dW2
b2 += -LEARNING_RATE * db2

# %% [markdown]
# ## Training

# %% [markdown]
# 6. Repeat steps 2 - 4 until model performs well.

# %%
# Initialize random weights
W1 = 0.01 * np.random.randn(INPUT_DIM, HIDDEN_DIM)
b1 = np.zeros((1, HIDDEN_DIM))
W2 = 0.01 * np.random.randn(HIDDEN_DIM, NUM_CLASSES)
b2 = np.zeros((1, NUM_CLASSES))

# Training loop
for epoch_num in range(1000):

    # First layer forward pass [NX2] · [2X100] = [NX100]
    z1 = np.dot(X_train, W1) + b1

    # Apply activation function
    a1 = np.maximum(0, z1) # ReLU

    # z2 = logits = [NX100] · [100X3] = [NX3]
    logits = np.dot(a1, W2) + b2
    
    # Normalization via softmax to obtain class probabilities
    exp_logits = np.exp(logits)
    y_hat = exp_logits / np.sum(exp_logits, axis=1, keepdims=True)

    # Loss
    correct_class_logprobs = -np.log(y_hat[range(len(y_hat)), y_train])
    loss = np.sum(correct_class_logprobs) / len(y_train)

    # show progress
    if epoch_num%100 == 0:
        # Accuracy
        y_pred = np.argmax(logits, axis=1)
        accuracy =  np.mean(np.equal(y_train, y_pred))
        print (f"Epoch: {epoch_num}, loss: {loss:.3f}, accuracy: {accuracy:.3f}")

    # dJ/dW2
    dscores = y_hat
    dscores[range(len(y_hat)), y_train] -= 1
    dscores /= len(y_train)
    dW2 = np.dot(a1.T, dscores)
    db2 = np.sum(dscores, axis=0, keepdims=True)

    # dJ/dW1
    dhidden = np.dot(dscores, W2.T)
    dhidden[a1 <= 0] = 0 # ReLu backprop
    dW1 = np.dot(X_train.T, dhidden)
    db1 = np.sum(dhidden, axis=0, keepdims=True)

    # Update weights
    W1 += -1e0 * dW1
    b1 += -1e0 * db1
    W2 += -1e0 * dW2
    b2 += -1e0 * db2
# Out:
# Epoch: 0, loss: 1.099, accuracy: 0.243
# Epoch: 100, loss: 0.551, accuracy: 0.680
# Epoch: 200, loss: 0.223, accuracy: 0.912
# Epoch: 300, loss: 0.131, accuracy: 0.951
# Epoch: 400, loss: 0.090, accuracy: 0.976
# Epoch: 500, loss: 0.069, accuracy: 0.985
# Epoch: 600, loss: 0.056, accuracy: 0.994
# Epoch: 700, loss: 0.048, accuracy: 0.996
# Epoch: 800, loss: 0.043, accuracy: 0.997
# Epoch: 900, loss: 0.039, accuracy: 0.997

# %%
class MLPFromScratch():
    def predict(self, x):
        z1 = np.dot(x, W1) + b1
        a1 = np.maximum(0, z1)
        logits = np.dot(a1, W2) + b2
        exp_logits = np.exp(logits)
        y_hat = exp_logits / np.sum(exp_logits, axis=1, keepdims=True)
        return y_hat

# %%
# Evaluation
model = MLPFromScratch()
logits_train = model.predict(X_train)
pred_train = np.argmax(logits_train, axis=1)
logits_test = model.predict(X_test)
pred_test = np.argmax(logits_test, axis=1)

# %%
# Training and test accuracy
train_acc =  np.mean(np.equal(y_train, pred_train))
test_acc = np.mean(np.equal(y_test, pred_test))
print (f"train acc: {train_acc:.2f}, test acc: {test_acc:.2f}")
# Out:
# train acc: 1.00, test acc: 1.00

# %%
# Visualize the decision boundary
plt.figure(figsize=(12,5))
plt.subplot(1, 2, 1)
plt.title("Train")
plot_multiclass_decision_boundary(model=model, X=X_train, y=y_train)
plt.subplot(1, 2, 2)
plt.title("Test")
plot_multiclass_decision_boundary(model=model, X=X_test, y=y_test)
plt.show()

# %% [markdown]
# Credit for the plotting functions and the intuition behind all this is due to [CS231n](http://cs231n.github.io/neural-networks-case-study/), one of the best courses for machine learning. Now let's implement the MLP with TensorFlow + Keras.

# %% [markdown]
# # TensorFlow + Keras

# %% [markdown]
# ## Model

# %%
class MLP(Model):
    def __init__(self, hidden_dim, num_classes):
        super(MLP, self).__init__(name='mlp')
        self.fc1 = Dense(units=hidden_dim, activation='relu', name='W1')
        self.fc2 = Dense(units=num_classes, activation='softmax', name='W2')
        
    def call(self, x_in, training=False):
        z = self.fc1(x_in)
        y_pred = self.fc2(z)
        return y_pred

    def summary(self, input_shape):
        x_in = Input(shape=input_shape, name='X')
        summary = Model(inputs=x_in, outputs=self.call(x_in), name=self.name)
        summary.summary() # parameter summary
        print ("\n\nWEIGHTS:") # weights summary
        for layer in self.layers:
            print ("_"*50)
            print (layer.name)
            for w in layer.weights:
                print (f"\t{w.name} → {w.shape}")
        print ("\n\nFORWARD PASS:")
        return plot_model(summary, show_shapes=True) # forward pass

# %%
# Initialize model
model = MLP(hidden_dim=HIDDEN_DIM, num_classes=NUM_CLASSES)

# %%
# Summary
model.summary(input_shape=(INPUT_DIM,))
# Out:
# Model: "mlp"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# X (InputLayer)               [(None, 2)]               0
# _________________________________________________________________
# W1 (Dense)                   (None, 100)               300
# _________________________________________________________________
# W2 (Dense)                   (None, 3)                 303
# =================================================================
# Total params: 603
# Trainable params: 603
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Training

# %%
# Compile
model.compile(optimizer=Adam(lr=LEARNING_RATE),
              loss=SparseCategoricalCrossentropy(),
              metrics=[SparseCategoricalAccuracy()])

# %%
# Training
model.fit(x=X_train, 
          y=y_train,
          validation_data=(X_val, y_val),
          epochs=NUM_EPOCHS,
          batch_size=BATCH_SIZE,
          class_weight=class_weights,
          shuffle=False,
          verbose=1)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 1083 samples, validate on 192 samples
# Epoch 1/10
# 1083/1083 [==============================] - 0s 422us/sample - loss: 0.0021 - sparse_categorical_accuracy: 0.5540 - val_loss: 0.0017 - val_sparse_categorical_accuracy: 0.5833
# Epoch 2/10
# 1083/1083 [==============================] - 0s 126us/sample - loss: 0.0014 - sparse_categorical_accuracy: 0.7470 - val_loss: 0.0012 - val_sparse_categorical_accuracy: 0.8333
# Epoch 3/10
# 1083/1083 [==============================] - 0s 99us/sample - loss: 8.5693e-04 - sparse_categorical_accuracy: 0.9049 - val_loss: 7.6481e-04 - val_sparse_categorical_accuracy: 0.8906
# Epoch 4/10
# 1083/1083 [==============================] - 0s 98us/sample - loss: 5.4156e-04 - sparse_categorical_accuracy: 0.9501 - val_loss: 5.5680e-04 - val_sparse_categorical_accuracy: 0.9531
# Epoch 5/10
# 1083/1083 [==============================] - 0s 113us/sample - loss: 3.8934e-04 - sparse_categorical_accuracy: 0.9649 - val_loss: 4.4130e-04 - val_sparse_categorical_accuracy: 0.9635
# Epoch 6/10
# 1083/1083 [==============================] - 0s 117us/sample - loss: 3.0538e-04 - sparse_categorical_accuracy: 0.9741 - val_loss: 3.6685e-04 - val_sparse_categorical_accuracy: 0.9635
# Epoch 7/10
# 1083/1083 [==============================] - 0s 119us/sample - loss: 2.5231e-04 - sparse_categorical_accuracy: 0.9778 - val_loss: 3.0834e-04 - val_sparse_categorical_accuracy: 0.9792
# Epoch 8/10
# 1083/1083 [==============================] - 0s 116us/sample - loss: 2.1546e-04 - sparse_categorical_accuracy: 0.9815 - val_loss: 2.6535e-04 - val_sparse_categorical_accuracy: 0.9948
# Epoch 9/10
# 1083/1083 [==============================] - 0s 119us/sample - loss: 1.8842e-04 - sparse_categorical_accuracy: 0.9834 - val_loss: 2.3150e-04 - val_sparse_categorical_accuracy: 0.9948
# Epoch 10/10
# 1083/1083 [==============================] - 0s 108us/sample - loss: 1.6813e-04 - sparse_categorical_accuracy: 0.9843 - val_loss: 2.0421e-04 - val_sparse_categorical_accuracy: 0.9948

# %% [markdown]
# ## Evaluation

# %%
# Predictions
pred_train = model.predict(X_train) 
pred_test = model.predict(X_test)
print (f"sample probability: {pred_test[0]}")
pred_train = np.argmax(pred_train, axis=1)
pred_test = np.argmax(pred_test, axis=1)
print (f"sample class: {pred_test[0]}")
# Out:
# sample probability: [1.2430343e-03 5.1018625e-04 9.9824679e-01]
# sample class: 2

# %%
# Accuracy
train_acc = accuracy_score(y_train, pred_train)
test_acc = accuracy_score(y_test, pred_test)
print (f"train acc: {train_acc:.2f}, test acc: {test_acc:.2f}")
# Out:
# train acc: 0.99, test acc: 0.99

# %%
# Metrics
plot_confusion_matrix(y_test, pred_test, classes=classes)
print (classification_report(y_test, pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99        75
#            1       1.00      0.99      0.99        75
#            2       0.99      1.00      0.99        75
#
#     accuracy                           0.99       225
#    macro avg       0.99      0.99      0.99       225
# weighted avg       0.99      0.99      0.99       225

# %%
# Visualize the decision boundary
plt.figure(figsize=(12,5))
plt.subplot(1, 2, 1)
plt.title("Train")
plot_multiclass_decision_boundary(model=model, X=X_train, y=y_train)
plt.subplot(1, 2, 2)
plt.title("Test")
plot_multiclass_decision_boundary(model=model, X=X_test, y=y_test)
plt.show()

# %% [markdown]
# ## Inference

# %%
# Inputs for inference
X_infer = pd.DataFrame([{'X1': 0.1, 'X2': 0.1}])
X_infer.head()
# Out:
#     X1   X2
# 0  0.1  0.1

# %%
# Standardize
X_infer = X_scaler.transform(X_infer)
print (X_infer)
# Out:
# [[0.30945845 0.30761858]]

# %%
# Predict
y_infer = model.predict(X_infer)
_class = np.argmax(y_infer)
print (f"The probability that you have a class {classes[_class]} is {y_infer[0][_class]*100.0:.0f}%")
# Out:
# The probability that you have a class c1 is 97%

# %% [markdown]
# # Initializing weights

# %% [markdown]
# So far we have been initializing weights with small random values and this isn't optimal for convergence during training. The objective is to have weights that are able to produce outputs that follow a similar distribution across all neurons. We can do this by enforcing weights to have unit variance prior the affine and non-linear operations.

# %% [markdown]
# **NOTE**: A popular method is to apply [xavier initialization](http://andyljones.tumblr.com/post/110998971763/an-explanation-of-xavier-initialization), which essentially initializes the weights to allow the signal from the data to reach deep into the network. You may be wondering why we don't do this for every forward pass and that's a great question. We'll look at more advanced strategies that help with optimization like batch/layer normalization, etc. in future lessons. Meanwhile you can check out other initializers [here](https://www.tensorflow.org/versions/r2.0/api_docs/python/tf/initializers).

# %%
from tensorflow.keras.initializers import glorot_normal

# %%
# Dense layer with glorot initializer
z = Dense(HIDDEN_DIM, activation='relu', kernel_initializer=glorot_normal(), name='W1') # xavier glorot initiailization

# %% [markdown]
# # Dropout

# %% [markdown]
# A great technique to overcome overfitting is to increase the size of your data but this isn't always an option. Fortuntely, there are methods like regularization and dropout that can help create a more robust model.
#
# Dropout is a technique (used only during training) that allows us to zero the outputs of neurons. We do this for `dropout_p`% of the total neurons in each layer and it changes every batch. Dropout prevents units from co-adapting too much to the data and acts as a sampling strategy since we drop a different set of neurons each time.
#
# <img src="https://raw.githubusercontent.com/practicalAI/images/master/basic_ml/06_Multilayer_Perceptron/dropout.png" width="350">
#
# * [Dropout: A Simple Way to Prevent Neural Networks from
# Overfitting](http://jmlr.org/papers/volume15/srivastava14a/srivastava14a.pdf)

# %%
from tensorflow.keras.layers import Dropout
from tensorflow.keras.regularizers import l2

# %%
DROPOUT_P = 0.1 # % of the neurons that are dropped each pass
LAMBDA_L2 = 1e-4 # L2 regularization

# %%
class MLPWithDropout(Model):
    def __init__(self, hidden_dim, lambda_l2, dropout_p, num_classes):
        super(MLPWithDropout, self).__init__(name='mlp_with_dropout')
        self.fc1 = Dense(units=hidden_dim, activation='relu', 
                         kernel_initializer=glorot_normal(), 
                         kernel_regularizer=l2(lambda_l2), # adding L2 regularization
                         name='W1')
        self.dropout = Dropout(rate=dropout_p, name='dropout')
        self.fc2 = Dense(units=num_classes, activation='softmax', name='W2')
        
    def call(self, x_in, training=False):
        z = self.fc1(x_in)
        z = self.dropout(z, training=training)
        y_pred = self.fc2(z)
        return y_pred
    
    def summary(self, input_shape):
        x_in = Input(shape=input_shape, name='X')
        summary = Model(inputs=x_in, outputs=self.call(x_in), name=self.name)
        summary.summary() # parameter summary
        print ("\n\nWEIGHTS:") # weights summary
        for layer in self.layers:
            print ("_"*50)
            print (layer.name)
            for w in layer.weights:
                print (f"\t{w.name} → {w.shape}")
        print ("\n\nFORWARD PASS:")
        return plot_model(summary, show_shapes=True) # forward pass

# %%
# Initialize model
model = MLPWithDropout(hidden_dim=HIDDEN_DIM, lambda_l2=LAMBDA_L2, 
                       dropout_p=DROPOUT_P, num_classes=NUM_CLASSES)

# %%
# Summary
model.summary(input_shape=(INPUT_DIM,))
# Out:
# Model: "mlp_with_dropout"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# X (InputLayer)               [(None, 2)]               0
# _________________________________________________________________
# W1 (Dense)                   (None, 100)               300
# _________________________________________________________________
# dropout (Dropout)            (None, 100)               0
# _________________________________________________________________
# W2 (Dense)                   (None, 3)                 303
# =================================================================
# Total params: 603
# Trainable params: 603
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Overfitting

# %% [markdown]
# Though neural networks are great at capturing non-linear relationships they are highly susceptible to overfitting to the training data and failing to generalize on test data. Just take a look at the example below where we generate completely random data and are able to fit a model with [$2*N*C + D$](https://arxiv.org/abs/1611.03530) hidden units. The training performance is good (~70%) but the overfitting leads to very poor test performance. We'll be covering strategies to tackle overfitting in future lessons.

# %%
NUM_EPOCHS = 500
NUM_SAMPLES_PER_CLASS = 50
LEARNING_RATE = 1e-1
HIDDEN_DIM = 2 * NUM_SAMPLES_PER_CLASS * NUM_CLASSES + INPUT_DIM # 2*N*C + D

# %%
# Generate random data
X = np.random.rand(NUM_SAMPLES_PER_CLASS * NUM_CLASSES, INPUT_DIM)
y = np.array([[i]*NUM_SAMPLES_PER_CLASS for i in range(NUM_CLASSES)]).reshape(-1)
print ("X: ", format(np.shape(X)))
print ("y: ", format(np.shape(y)))
# Out:
# X:  (150, 2)
# y:  (150,)

# %%
# Create data splits
X_train, X_val, X_test, y_train, y_val, y_test = train_val_test_split(
    X, y, val_size=VAL_SIZE, test_size=TEST_SIZE, shuffle=SHUFFLE)
print ("X_train:", X_train.shape)
print ("y_train:", y_train.shape)
print ("X_val:", X_val.shape)
print ("y_val:", y_val.shape)
print ("X_test:", X_test.shape)
print ("y_test:", y_test.shape)
# Out:
# X_train: (107, 2)
# y_train: (107,)
# X_val: (20, 2)
# y_val: (20,)
# X_test: (23, 2)
# y_test: (23,)

# %%
# Standardize the inputs (mean=0, std=1) using training data
X_scaler = StandardScaler().fit(X_train)
X_train = X_scaler.transform(X_train)
X_val = X_scaler.transform(X_val)
X_test = X_scaler.transform(X_test)

# %%
class OverfitMLP(Model):
    def __init__(self, hidden_dim, num_classes):
        super(OverfitMLP, self).__init__(name='overfit_mlp')
        self.fc1 = Dense(units=hidden_dim, activation='relu', name='W1')
        self.fc2 = Dense(units=num_classes, activation='softmax', name='W2')
        
    def call(self, x_in, training=False):
        z = self.fc1(x_in)
        y_pred = self.fc2(z)
        return y_pred
    
    def summary(self, input_shape):
        x_in = Input(shape=input_shape, name='X')
        summary = Model(inputs=x_in, outputs=self.call(x_in), name=self.name)
        summary.summary() # parameter summary
        print ("\n\nWEIGHTS:") # weights summary
        for layer in self.layers:
            print ("_"*50)
            print (layer.name)
            for w in layer.weights:
                print (f"\t{w.name} → {w.shape}")
        print ("\n\nFORWARD PASS:")
        return plot_model(summary, show_shapes=True) # forward pass

# %%
# Initialize model
model = OverfitMLP(hidden_dim=HIDDEN_DIM, num_classes=NUM_CLASSES)

# %%
# Summary
model.summary(input_shape=(INPUT_DIM,))
# Out:
# Model: "overfit_mlp"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# X (InputLayer)               [(None, 2)]               0
# _________________________________________________________________
# W1 (Dense)                   (None, 302)               906
# _________________________________________________________________
# W2 (Dense)                   (None, 3)                 909
# =================================================================
# Total params: 1,815
# Trainable params: 1,815
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile
optimizer = Adam(lr=LEARNING_RATE)
model.compile(optimizer=optimizer,
              loss=SparseCategoricalCrossentropy(),
              metrics=[SparseCategoricalAccuracy()])

# %%
# Training
model.fit(x=X_train, 
          y=y_train,
          validation_data=(X_val, y_val),
          epochs=NUM_EPOCHS,
          batch_size=BATCH_SIZE,
          class_weight=class_weights,
          shuffle=False,
          verbose=1)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 107 samples, validate on 20 samples
# Epoch 1/500
# 107/107 [==============================] - 0s 4ms/sample - loss: 0.0044 - sparse_categorical_accuracy: 0.2336 - val_loss: 0.0035 - val_sparse_categorical_accuracy: 0.3000
# Epoch 2/500
# 107/107 [==============================] - 0s 229us/sample - loss: 0.0034 - sparse_categorical_accuracy: 0.1963 - val_loss: 0.0032 - val_sparse_categorical_accuracy: 0.4500
# Epoch 3/500
# 107/107 [==============================] - 0s 219us/sample - loss: 0.0033 - sparse_categorical_accuracy: 0.4486 - val_loss: 0.0029 - val_sparse_categorical_accuracy: 0.4000
# Epoch 4/500
# 107/107 [==============================] - 0s 221us/sample - loss: 0.0031 - sparse_categorical_accuracy: 0.3925 - val_loss: 0.0030 - val_sparse_categorical_accuracy: 0.3500
# Epoch 5/500
# 107/107 [==============================] - 0s 220us/sample - loss: 0.0030 - sparse_categorical_accuracy: 0.4393 - val_loss: 0.0028 - val_sparse_categorical_accuracy: 0.4500
# Epoch 6/500
# 107/107 [==============================] - 0s 193us/sample - loss: 0.0030 - sparse_categorical_accuracy: 0.4673 - val_loss: 0.0029 - val_sparse_categorical_accuracy: 0.3000
# Epoch 7/500
# 107/107 [==============================] - 0s 210us/sample - loss: 0.0028 - sparse_categorical_accuracy: 0.5047 - val_loss: 0.0032 - val_sparse_categorical_accuracy: 0.3500
# Epoch 8/500
# 107/107 [==============================] - 0s 226us/sample - loss: 0.0030 - sparse_categorical_accuracy: 0.4953 - val_loss: 0.0030 - val_sparse_categorical_accuracy: 0.3500
# Epoch 9/500
# 107/107 [==============================] - 0s 209us/sample - loss: 0.0028 - sparse_categorical_accuracy: 0.5047 - val_loss: 0.0031 - val_sparse_categorical_accuracy: 0.4000
# Epoch 10/500
# 107/107 [==============================] - 0s 211us/sample - loss: 0.0028 - sparse_categorical_accuracy: 0.4860 - val_loss: 0.0030 - val_sparse_categorical_accuracy: 0.4000
# Epoch 11/500
# 107/107 [==============================] - 0s 221us/sample - loss: 0.0027 - sparse_categorical_accuracy: 0.5047 - val_loss: 0.0031 - val_sparse_categorical_accuracy: 0.4000
# Epoch 12/500
# 107/107 [==============================] - 0s 222us/sample - loss: 0.0028 - sparse_categorical_accuracy: 0.4953 - val_loss: 0.0029 - val_sparse_categorical_accuracy: 0.5000
# Epoch 13/500
# 107/107 [==============================] - 0s 223us/sample - loss: 0.0027 - sparse_categorical_accuracy: 0.5514 - val_loss: 0.0032 - val_sparse_categorical_accuracy: 0.4500
# Epoch 14/500
# 107/107 [==============================] - 0s 213us/sample - loss: 0.0028 - sparse_categorical_accuracy: 0.5140 - val_loss: 0.0029 - val_sparse_categorical_accuracy: 0.5000
# Epoch 15/500
# 107/107 [==============================] - 0s 224us/sample - loss: 0.0027 - sparse_categorical_accuracy: 0.5514 - val_loss: 0.0032 - val_sparse_categorical_accuracy: 0.5000
# Epoch 16/500
# 107/107 [==============================] - 0s 278us/sample - loss: 0.0028 - sparse_categorical_accuracy: 0.5421 - val_loss: 0.0029 - val_sparse_categorical_accuracy: 0.5500
# Epoch 17/500
# 107/107 [==============================] - 0s 240us/sample - loss: 0.0027 - sparse_categorical_accuracy: 0.5514 - val_loss: 0.0032 - val_sparse_categorical_accuracy: 0.5000
# Epoch 18/500
# 107/107 [==============================] - 0s 310us/sample - loss: 0.0028 - sparse_categorical_accuracy: 0.5327 - val_loss: 0.0029 - val_sparse_categorical_accuracy: 0.5000
# Epoch 19/500
# 107/107 [==============================] - 0s 227us/sample - loss: 0.0027 - sparse_categorical_accuracy: 0.5421 - val_loss: 0.0031 - val_sparse_categorical_accuracy: 0.5500
# Epoch 20/500
# 107/107 [==============================] - 0s 293us/sample - loss: 0.0028 - sparse_categorical_accuracy: 0.5234 - val_loss: 0.0030 - val_sparse_categorical_accuracy: 0.4000
# Epoch 21/500
# 107/107 [==============================] - 0s 224us/sample - loss: 0.0028 - sparse_categorical_accuracy: 0.4673 - val_loss: 0.0030 - val_sparse_categorical_accuracy: 0.5000
# Epoch 22/500
# 107/107 [==============================] - 0s 246us/sample - loss: 0.0028 - sparse_categorical_accuracy: 0.5234 - val_loss: 0.0034 - val_sparse_categorical_accuracy: 0.4500
# Epoch 23/500
# 107/107 [==============================] - 0s 214us/sample - loss: 0.0029 - sparse_categorical_accuracy: 0.4860 - val_loss: 0.0031 - val_sparse_categorical_accuracy: 0.4500
# Epoch 24/500
# 107/107 [==============================] - 0s 247us/sample - loss: 0.0029 - sparse_categorical_accuracy: 0.5047 - val_loss: 0.0029 - val_sparse_categorical_accuracy: 0.6000
# Epoch 25/500
# 107/107 [==============================] - 0s 215us/sample - loss: 0.0026 - sparse_categorical_accuracy: 0.5607 - val_loss: 0.0033 - val_sparse_categorical_accuracy: 0.5000
# Epoch 26/500
# 107/107 [==============================] - 0s 302us/sample - loss: 0.0028 - sparse_categorical_accuracy: 0.5981 - val_loss: 0.0029 - val_sparse_categorical_accuracy: 0.5500
# Epoch 27/500
# 107/107 [==============================] - 0s 281us/sample - loss: 0.0026 - sparse_categorical_accuracy: 0.4953 - val_loss: 0.0029 - val_sparse_categorical_accuracy: 0.6500
# Epoch 28/500
# 107/107 [==============================] - 0s 211us/sample - loss: 0.0026 - sparse_categorical_accuracy: 0.5701 - val_loss: 0.0031 - val_sparse_categorical_accuracy: 0.5000
# Epoch 29/500
# 107/107 [==============================] - 0s 218us/sample - loss: 0.0026 - sparse_categorical_accuracy: 0.5514 - val_loss: 0.0030 - val_sparse_categorical_accuracy: 0.5500
# Epoch 30/500
# 107/107 [==============================] - 0s 273us/sample - loss: 0.0026 - sparse_categorical_accuracy: 0.5888 - val_loss: 0.0031 - val_sparse_categorical_accuracy: 0.5500
# Epoch 31/500
# 107/107 [==============================] - 0s 289us/sample - loss: 0.0026 - sparse_categorical_accuracy: 0.5514 - val_loss: 0.0029 - val_sparse_categorical_accuracy: 0.5500
# Epoch 32/500
# 107/107 [==============================] - 0s 243us/sample - loss: 0.0028 - sparse_categorical_accuracy: 0.5421 - val_loss: 0.0030 - val_sparse_categorical_accuracy: 0.5000
# Epoch 33/500
# 107/107 [==============================] - 0s 225us/sample - loss: 0.0026 - sparse_categorical_accuracy: 0.5327 - val_loss: 0.0028 - val_sparse_categorical_accuracy: 0.6000
# Epoch 34/500
# 107/107 [==============================] - 0s 236us/sample - loss: 0.0026 - sparse_categorical_accuracy: 0.6075 - val_loss: 0.0032 - val_sparse_categorical_accuracy: 0.5500
# Epoch 35/500
# 107/107 [==============================] - 0s 271us/sample - loss: 0.0026 - sparse_categorical_accuracy: 0.5701 - val_loss: 0.0029 - val_sparse_categorical_accuracy: 0.5500
# Epoch 36/500
# 107/107 [==============================] - 0s 231us/sample - loss: 0.0025 - sparse_categorical_accuracy: 0.5607 - val_loss: 0.0032 - val_sparse_categorical_accuracy: 0.6000
# Epoch 37/500
# 107/107 [==============================] - 0s 244us/sample - loss: 0.0025 - sparse_categorical_accuracy: 0.5607 - val_loss: 0.0028 - val_sparse_categorical_accuracy: 0
/sample - loss: 0.0018 - sparse_categorical_accuracy: 0.7290 - val_loss: 0.0057 - val_sparse_categorical_accuracy: 0.5000
# Epoch 455/500
# 107/107 [==============================] - 0s 270us/sample - loss: 0.0019 - sparse_categorical_accuracy: 0.6916 - val_loss: 0.0054 - val_sparse_categorical_accuracy: 0.5000
# Epoch 456/500
# 107/107 [==============================] - 0s 218us/sample - loss: 0.0018 - sparse_categorical_accuracy: 0.7196 - val_loss: 0.0064 - val_sparse_categorical_accuracy: 0.5500
# Epoch 457/500
# 107/107 [==============================] - 0s 198us/sample - loss: 0.0018 - sparse_categorical_accuracy: 0.7009 - val_loss: 0.0053 - val_sparse_categorical_accuracy: 0.5000
# Epoch 458/500
# 107/107 [==============================] - 0s 293us/sample - loss: 0.0018 - sparse_categorical_accuracy: 0.7103 - val_loss: 0.0065 - val_sparse_categorical_accuracy: 0.5000
# Epoch 459/500
# 107/107 [==============================] - 0s 238us/sample - loss: 0.0019 - sparse_categorical_accuracy: 0.6916 - val_loss: 0.0054 - val_sparse_categorical_accuracy: 0.6000
# Epoch 460/500
# 107/107 [==============================] - 0s 252us/sample - loss: 0.0019 - sparse_categorical_accuracy: 0.7290 - val_loss: 0.0062 - val_sparse_categorical_accuracy: 0.5000
# Epoch 461/500
# 107/107 [==============================] - 0s 251us/sample - loss: 0.0019 - sparse_categorical_accuracy: 0.6636 - val_loss: 0.0058 - val_sparse_categorical_accuracy: 0.5500
# Epoch 462/500
# 107/107 [==============================] - 0s 252us/sample - loss: 0.0018 - sparse_categorical_accuracy: 0.7477 - val_loss: 0.0058 - val_sparse_categorical_accuracy: 0.4500
# Epoch 463/500
# 107/107 [==============================] - 0s 241us/sample - loss: 0.0018 - sparse_categorical_accuracy: 0.7290 - val_loss: 0.0055 - val_sparse_categorical_accuracy: 0.5500
# Epoch 464/500
# 107/107 [==============================] - 0s 241us/sample - loss: 0.0016 - sparse_categorical_accuracy: 0.7290 - val_loss: 0.0059 - val_sparse_categorical_accuracy: 0.5500
# Epoch 465/500
# 107/107 [==============================] - 0s 266us/sample - loss: 0.0016 - sparse_categorical_accuracy: 0.7290 - val_loss: 0.0067 - val_sparse_categorical_accuracy: 0.6000
# Epoch 466/500
# 107/107 [==============================] - 0s 261us/sample - loss: 0.0017 - sparse_categorical_accuracy: 0.7477 - val_loss: 0.0053 - val_sparse_categorical_accuracy: 0.5500
# Epoch 467/500
# 107/107 [==============================] - 0s 233us/sample - loss: 0.0016 - sparse_categorical_accuracy: 0.6916 - val_loss: 0.0065 - val_sparse_categorical_accuracy: 0.5000
# Epoch 468/500
# 107/107 [==============================] - 0s 258us/sample - loss: 0.0019 - sparse_categorical_accuracy: 0.6822 - val_loss: 0.0043 - val_sparse_categorical_accuracy: 0.5500
# Epoch 469/500
# 107/107 [==============================] - 0s 198us/sample - loss: 0.0019 - sparse_categorical_accuracy: 0.6542 - val_loss: 0.0066 - val_sparse_categorical_accuracy: 0.4500
# Epoch 470/500
# 107/107 [==============================] - 0s 256us/sample - loss: 0.0020 - sparse_categorical_accuracy: 0.6542 - val_loss: 0.0048 - val_sparse_categorical_accuracy: 0.5500
# Epoch 471/500
# 107/107 [==============================] - 0s 289us/sample - loss: 0.0017 - sparse_categorical_accuracy: 0.7290 - val_loss: 0.0069 - val_sparse_categorical_accuracy: 0.4500
# Epoch 472/500
# 107/107 [==============================] - 0s 247us/sample - loss: 0.0017 - sparse_categorical_accuracy: 0.7103 - val_loss: 0.0049 - val_sparse_categorical_accuracy: 0.6500
# Epoch 473/500
# 107/107 [==============================] - 0s 270us/sample - loss: 0.0016 - sparse_categorical_accuracy: 0.7477 - val_loss: 0.0070 - val_sparse_categorical_accuracy: 0.5000
# Epoch 474/500
# 107/107 [==============================] - 0s 215us/sample - loss: 0.0019 - sparse_categorical_accuracy: 0.6822 - val_loss: 0.0048 - val_sparse_categorical_accuracy: 0.5000
# Epoch 475/500
# 107/107 [==============================] - 0s 248us/sample - loss: 0.0019 - sparse_categorical_accuracy: 0.7290 - val_loss: 0.0072 - val_sparse_categorical_accuracy: 0.5000
# Epoch 476/500
# 107/107 [==============================] - 0s 213us/sample - loss: 0.0022 - sparse_categorical_accuracy: 0.6636 - val_loss: 0.0044 - val_sparse_categorical_accuracy: 0.5000
# Epoch 477/500
# 107/107 [==============================] - 0s 215us/sample - loss: 0.0021 - sparse_categorical_accuracy: 0.7196 - val_loss: 0.0071 - val_sparse_categorical_accuracy: 0.5000
# Epoch 478/500
# 107/107 [==============================] - 0s 212us/sample - loss: 0.0021 - sparse_categorical_accuracy: 0.6916 - val_loss: 0.0047 - val_sparse_categorical_accuracy: 0.6500
# Epoch 479/500
# 107/107 [==============================] - 0s 229us/sample - loss: 0.0018 - sparse_categorical_accuracy: 0.7290 - val_loss: 0.0064 - val_sparse_categorical_accuracy: 0.5000
# Epoch 480/500
# 107/107 [==============================] - 0s 223us/sample - loss: 0.0018 - sparse_categorical_accuracy: 0.7009 - val_loss: 0.0054 - val_sparse_categorical_accuracy: 0.6000
# Epoch 481/500
# 107/107 [==============================] - 0s 270us/sample - loss: 0.0017 - sparse_categorical_accuracy: 0.7570 - val_loss: 0.0060 - val_sparse_categorical_accuracy: 0.5000
# Epoch 482/500
# 107/107 [==============================] - 0s 248us/sample - loss: 0.0017 - sparse_categorical_accuracy: 0.7103 - val_loss: 0.0056 - val_sparse_categorical_accuracy: 0.6000
# Epoch 483/500
# 107/107 [==============================] - 0s 290us/sample - loss: 0.0018 - sparse_categorical_accuracy: 0.7196 - val_loss: 0.0068 - val_sparse_categorical_accuracy: 0.5500
# Epoch 484/500
# 107/107 [==============================] - 0s 253us/sample - loss: 0.0017 - sparse_categorical_accuracy: 0.7290 - val_loss: 0.0056 - val_sparse_categorical_accuracy: 0.5000
# Epoch 485/500
# 107/107 [==============================] - 0s 252us/sample - loss: 0.0017 - sparse_categorical_accuracy: 0.7477 - val_loss: 0.0061 - val_sparse_categorical_accuracy: 0.5000
# Epoch 486/500
# 107/107 [==============================] - 0s 362us/sample - loss: 0.0018 - sparse_categorical_accuracy: 0.7290 - val_loss: 0.0057 - val_sparse_categorical_accuracy: 0.5000
# Epoch 487/500
# 107/107 [==============================] - 0s 267us/sample - loss: 0.0017 - sparse_categorical_accuracy: 0.7290 - val_loss: 0.0066 - val_sparse_categorical_accuracy: 0.5000
# Epoch 488/500
# 107/107 [==============================] - 0s 260us/sample - loss: 0.0018 - sparse_categorical_accuracy: 0.7103 - val_loss: 0.0055 - val_sparse_categorical_accuracy: 0.5500
# Epoch 489/500
# 107/107 [==============================] - 0s 244us/sample - loss: 0.0018 - sparse_categorical_accuracy: 0.7290 - val_loss: 0.0074 - val_sparse_categorical_accuracy: 0.5000
# Epoch 490/500
# 107/107 [==============================] - 0s 252us/sample - loss: 0.0020 - sparse_categorical_accuracy: 0.6822 - val_loss: 0.0053 - val_sparse_categorical_accuracy: 0.5500
# Epoch 491/500
# 107/107 [==============================] - 0s 229us/sample - loss: 0.0019 - sparse_categorical_accuracy: 0.7196 - val_loss: 0.0070 - val_sparse_categorical_accuracy: 0.5000
# Epoch 492/500
# 107/107 [==============================] - 0s 221us/sample - loss: 0.0020 - sparse_categorical_accuracy: 0.6822 - val_loss: 0.0050 - val_sparse_categorical_accuracy: 0.6500
# Epoch 493/500
# 107/107 [==============================] - 0s 215us/sample - loss: 0.0018 - sparse_categorical_accuracy: 0.7290 - val_loss: 0.0070 - val_sparse_categorical_accuracy: 0.4500
# Epoch 494/500
# 107/107 [==============================] - 0s 200us/sample - loss: 0.0019 - sparse_categorical_accuracy: 0.7009 - val_loss: 0.0051 - val_sparse_categorical_accuracy: 0.6000
# Epoch 495/500
# 107/107 [==============================] - 0s 224us/sample - loss: 0.0017 - sparse_categorical_accuracy: 0.7477 - val_loss: 0.0065 - val_sparse_categorical_accuracy: 0.5000
# Epoch 496/500
# 107/107 [==============================] - 0s 275us/sample - loss: 0.0018 - sparse_categorical_accuracy: 0.7383 - val_loss: 0.0055 - val_sparse_categorical_accuracy: 0.5500
# Epoch 497/500
# 107/107 [==============================] - 0s 277us/sample - loss: 0.0017 - sparse_categorical_accuracy: 0.7570 - val_loss: 0.0062 - val_sparse_categorical_accuracy: 0.6000
# Epoch 498/500
# 107/107 [==============================] - 0s 244us/sample - loss: 0.0016 - sparse_categorical_accuracy: 0.7570 - val_loss: 0.0062 - val_sparse_categorical_accuracy: 0.4500
# Epoch 499/500
# 107/107 [==============================] - 0s 232us/sample - loss: 0.0017 - sparse_categorical_accuracy: 0.7570 - val_loss: 0.0061 - val_sparse_categorical_accuracy: 0.5000
# Epoch 500/500
# 107/107 [==============================] - 0s 258us/sample - loss: 0.0017 - sparse_categorical_accuracy: 0.7570 - val_loss: 0.0061 - val_sparse_categorical_accuracy: 0.5500

# %%
# Predictions
pred_train = model.predict(X_train) 
pred_test = model.predict(X_test)
print (f"sample probability: {pred_test[0]}")
pred_train = np.argmax(pred_train, axis=1)
pred_test = np.argmax(pred_test, axis=1)
print (f"sample class: {pred_test[0]}")
# Out:
# sample probability: [0.00820148 0.77263176 0.21916683]
# sample class: 1

# %%
# Accuracy
train_acc = accuracy_score(y_train, pred_train)
test_acc = accuracy_score(y_test, pred_test)
print (f"train acc: {train_acc:.2f}, test acc: {test_acc:.2f}")
# Out:
# train acc: 0.74, test acc: 0.30

# %%
# Classification report
plot_confusion_matrix(y_true=y_test, y_pred=pred_test, classes=classes)
print (classification_report(y_test, pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.38      0.38      0.38         8
#            1       0.30      0.38      0.33         8
#            2       0.20      0.14      0.17         7
#
#     accuracy                           0.30        23
#    macro avg       0.29      0.30      0.29        23
# weighted avg       0.30      0.30      0.30        23

# %%
# Visualize the decision boundary
plt.figure(figsize=(12,5))
plt.subplot(1, 2, 1)
plt.title("Train")
plot_multiclass_decision_boundary(model=model, X=X_train, y=y_train)
plt.subplot(1, 2, 2)
plt.title("Test")
plot_multiclass_decision_boundary(model=model, X=X_test, y=y_test)
plt.show()

# %% [markdown]
# It's important that we experiment, starting with simple models that underfit (high bias) and improve it towards a good fit. Starting with simple models (linear/logistic regression) let's us catch errors without the added complexity of more sophisticated models (neural networks).

# %% [markdown]
# <img src="https://raw.githubusercontent.com/practicalAI/images/master/basic_ml/06_Multilayer_Perceptron/fit.png" width="700">

# %% [markdown]
# ---
# Share and discover ML projects at <a href="https://madewithml.com/#newsletter">Made With ML</a>.
#
# <a class="ai-header-badge" target="_blank" href="https://github.com/practicalAI/practicalAI"><img src="https://img.shields.io/github/stars/practicalAI/practicalAI.svg?style=social&label=Star"></a>&nbsp;
# <a class="ai-header-badge" target="_blank" href="https://www.linkedin.com/company/madewithml"><img src="https://img.shields.io/badge/style--5eba00.svg?label=LinkedIn&logo=linkedin&style=social"></a>&nbsp;
# <a class="ai-header-badge" target="_blank" href="https://twitter.com/madewithml"><img src="https://img.shields.io/twitter/follow/madewithml.svg?label=Follow&style=social"></a>
